# %%
from keras.preprocessing.image import load_img, img_to_array
from keras import backend as K
import numpy as np
from keras.applications import vgg19
from scipy.optimize import fmin_l_bfgs_b
import matplotlib.pyplot 
import time

# %%
img_height = 573
img_width = 1020

# %%
def preprocess_image(image_path):
    img = load_img(image_path, target_size=(img_height, img_width))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg19.preprocess_input(img)
    return img

# %%
def deprocess_image(x):
    x[:, :, 0] += 103.939
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68
    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
target_image = K.constant(preprocess_image("/content/paysage.jpg"))
style_reference_image = K.constant(preprocess_image("/content/index.jpg"))
combination_image = K.placeholder((1, img_height, img_width, 3))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
input_tensor = K.concatenate([target_image,
                              style_reference_image,
                              combination_image], axis=0)

model = vgg19.VGG19(input_tensor=input_tensor,
                    weights='imagenet',
                    include_top=False)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.

# %%
def content_loss(base, combination):
    return K.sum(K.square(combination - base))

def gram_matrix(x):
    features = K.batch_flatten(K.permute_dimensions(x, (2, 0, 1)))
    gram = K.dot(features, K.transpose(features))
    return gram

def style_loss(style, combination):
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    size = img_height * img_width
    return K.sum(K.square(S - C)) / (4. * (channels ** 2) * (size ** 2))

# %%
def total_variation_loss(x):
    a = K.square(
            x[:, :img_height - 1, :img_width - 1, :] -
            x[:, 1:, :img_width - 1, :])
    b = K.square(
            x[:, :img_height - 1, :img_width - 1, :] -
            x[:, :img_height - 1, 1:, :])
    return K.sum(K.pow(a + b, 1.25))

# %%
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])
content_layer = 'block5_conv2'
style_layers = ['block1_conv1',
                'block2_conv1',
                'block3_conv1',
                'block4_conv1',
                'block5_conv1']

total_variation_weight = 1e-5
style_weight = 1.
content_weight = 0.0003125

# %%
loss = K.variable(0.)
layer_features = outputs_dict[content_layer]
target_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]

loss += content_weight * content_loss(target_image_features,
                                      combination_features)
for layer_name in style_layers:
    layer_features = outputs_dict[layer_name]

    reference_features = layer_features[1, :, :, :]
    combination_features = layer_features[2, :, :, :]

    sl = style_loss(reference_features, combination_features)
    loss += (style_weight / len(style_layers)) * sl

loss += total_variation_weight * total_variation_loss(combination_image)
# Out:
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.

# %%
grads = K.gradients(loss, combination_image)[0]
fetch_loss_and_grads = K.function([combination_image], [loss, grads])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
class Evaluator(object):

    def __init__(self):
        self.loss_value = None
        self.grads_values = None

    def loss(self, x):
        assert self.loss_value is None
        x = x.reshape((1, img_height, img_width, 3))
        outs = fetch_loss_and_grads([x])

        loss_value = outs[0]
        grad_values = outs[1].flatten().astype('float64')
        self.loss_value = loss_value
        self.grad_values = grad_values
        return self.loss_value

    def grads(self, x):
        assert self.loss_value is not None
        grad_values = np.copy(self.grad_values)
        self.loss_value = None
        self.grad_values = None
        return grad_values

# %%
evaluator = Evaluator()

# %%
result_prefix = 'my_result'
iterations = 300
x = preprocess_image("/content/paysage.jpg")
x = x.flatten()
for i in range(iterations):
    print('Start of iteration', i)
    start_time = time.time()


    x, min_val, info = fmin_l_bfgs_b(evaluator.loss,
                                     x,
                                     fprime=evaluator.grads,
                                     maxfun=20)
    print('Current loss value:', min_val)
    img = x.copy().reshape((img_height, img_width, 3))  
    img = deprocess_image(img)
    fname = result_prefix + '_at_iteration_%d.png' % i
    matplotlib.pyplot.imsave(fname, img)
    print('Image saved as', fname)
    end_time = time.time()
    print('Iteration %d completed in %ds' % (i, end_time - start_time))
# Out:
# Start of iteration 0
# Current loss value: 332316400.0
# Image saved as my_result_at_iteration_0.png
# Iteration 0 completed in 16s
# Start of iteration 1
# Current loss value: 133507130.0
# Image saved as my_result_at_iteration_1.png
# Iteration 1 completed in 16s
# Start of iteration 2
# Current loss value: 81307510.0
# Image saved as my_result_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 62550124.0
# Image saved as my_result_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 52252490.0
# Image saved as my_result_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 45432924.0
# Image saved as my_result_at_iteration_5.png
# Iteration 5 completed in 17s
# Start of iteration 6
# Current loss value: 40275224.0
# Image saved as my_result_at_iteration_6.png
# Iteration 6 completed in 17s
# Start of iteration 7
# Current loss value: 36559972.0
# Image saved as my_result_at_iteration_7.png
# Iteration 7 completed in 17s
# Start of iteration 8
# Current loss value: 33835924.0
# Image saved as my_result_at_iteration_8.png
# Iteration 8 completed in 17s
# Start of iteration 9
# Current loss value: 31619422.0
# Image saved as my_result_at_iteration_9.png
# Iteration 9 completed in 17s
# Start of iteration 10
# Current loss value: 29863100.0
# Image saved as my_result_at_iteration_10.png
# Iteration 10 completed in 17s
# Start of iteration 11
# Current loss value: 27401182.0
# Image saved as my_result_at_iteration_11.png
# Iteration 11 completed in 17s
# Start of iteration 12
# Current loss value: 25763902.0
# Image saved as my_result_at_iteration_12.png
# Iteration 12 completed in 17s
# Start of iteration 13
# Current loss value: 24477296.0
# Image saved as my_result_at_iteration_13.png
# Iteration 13 completed in 17s
# Start of iteration 14
# Current loss value: 23258756.0
# Image saved as my_result_at_iteration_14.png
# Iteration 14 completed in 17s
# Start of iteration 15
# Current loss value: 22383000.0
# Image saved as my_result_at_iteration_15.png
# Iteration 15 completed in 17s
# Start of iteration 16
# Current loss value: 21593546.0
# Image saved as my_result_at_iteration_16.png
# Iteration 16 completed in 17s
# Start of iteration 17
# Current loss value: 20964098.0
# Image saved as my_result_at_iteration_17.png
# Iteration 17 completed in 17s
# Start of iteration 18
# Current loss value: 19866650.0
# Image saved as my_result_at_iteration_18.png
# Iteration 18 completed in 17s
# Start of iteration 19
# Current loss value: 18973444.0
# Image saved as my_result_at_iteration_19.png
# Iteration 19 completed in 17s
# Start of iteration 20
# Current loss value: 18281832.0
# Image saved as my_result_at_iteration_20.png
# Iteration 20 completed in 17s
# Start of iteration 21
# Current loss value: 17686886.0
# Image saved as my_result_at_iteration_21.png
# Iteration 21 completed in 17s
# Start of iteration 22
# Current loss value: 17175972.0
# Image saved as my_result_at_iteration_22.png
# Iteration 22 completed in 17s
# Start of iteration 23
# Current loss value: 16697666.0
# Image saved as my_result_at_iteration_23.png
# Iteration 23 completed in 17s
# Start of iteration 24
# Current loss value: 16327185.0
# Image saved as my_result_at_iteration_24.png
# Iteration 24 completed in 17s
# Start of iteration 25
# Current loss value: 15814383.0
# Image saved as my_result_at_iteration_25.png
# Iteration 25 completed in 17s
# Start of iteration 26
# Current loss value: 15447482.0
# Image saved as my_result_at_iteration_26.png
# Iteration 26 completed in 17s
# Start of iteration 27
# Current loss value: 15083359.0
# Image saved as my_result_at_iteration_27.png
# Iteration 27 completed in 17s
# Start of iteration 28
# Current loss value: 14743767.0
# Image saved as my_result_at_iteration_28.png
# Iteration 28 completed in 17s
# Start of iteration 29
# Current loss value: 14481070.0
# Image saved as my_result_at_iteration_29.png
# Iteration 29 completed in 17s
# Start of iteration 30
# Current loss value: 14231429.0
# Image saved as my_result_at_iteration_30.png
# Iteration 30 completed in 17s
# Start of iteration 31
# Current loss value: 13910278.0
# Image saved as my_result_at_iteration_31.png
# Iteration 31 completed in 17s
# Start of iteration 32
# Current loss value: 13659761.0
# Image saved as my_result_at_iteration_32.png
# Iteration 32 completed in 17s
# Start of iteration 33
# Current loss value: 13438643.0
# Image saved as my_result_at_iteration_33.png
# Iteration 33 completed in 17s
# Start of iteration 34
# Current loss value: 13193617.0
# Image saved as my_result_at_iteration_34.png
# Iteration 34 completed in 17s
# Start of iteration 35
# Current loss value: 12989164.0
# Image saved as my_result_at_iteration_35.png
# Iteration 35 completed in 17s
# Start of iteration 36
# Current loss value: 12787209.0
# Image saved as my_result_at_iteration_36.png
# Iteration 36 completed in 17s
# Start of iteration 37
# Current loss value: 12609800.0
# Image saved as my_result_at_iteration_37.png
# Iteration 37 completed in 17s
# Start of iteration 38
# Current loss value: 12342902.0
# Image saved as my_result_at_iteration_38.png
# Iteration 38 completed in 17s
# Start of iteration 39
# Current loss value: 12135210.0
# Image saved as my_result_at_iteration_39.png
# Iteration 39 completed in 17s
# Start of iteration 40
# Current loss value: 11988870.0
# Image saved as my_result_at_iteration_40.png
# Iteration 40 completed in 17s
# Start of iteration 41
# Current loss value: 11813999.0
# Image saved as my_result_at_iteration_41.png
# Iteration 41 completed in 17s
# Start of iteration 42
# Current loss value: 11653886.0
# Image saved as my_result_at_iteration_42.png
# Iteration 42 completed in 17s
# Start of iteration 43
# Current loss value: 11506486.0
# Image saved as my_result_at_iteration_43.png
# Iteration 43 completed in 17s
# Start of iteration 44
# Current loss value: 11358041.0
# Image saved as my_result_at_iteration_44.png
# Iteration 44 completed in 17s
# Start of iteration 45
# Current loss value: 11202138.0
# Image saved as my_result_at_iteration_45.png
# Iteration 45 completed in 17s
# Start of iteration 46
# Current loss value: 11059904.0
# Image saved as my_result_at_iteration_46.png
# Iteration 46 completed in 17s
# Start of iteration 47
# Current loss value: 10924288.0
# Image saved as my_result_at_iteration_47.png
# Iteration 47 completed in 17s
# Start of iteration 48
# Current loss value: 10787669.0
# Image saved as my_result_at_iteration_48.png
# Iteration 48 completed in 17s
# Start of iteration 49
# Current loss value: 10655642.0
# Image saved as my_result_at_iteration_49.png
# Iteration 49 completed in 17s
# Start of iteration 50
# Current loss value: 10544966.0
# Image saved as my_result_at_iteration_50.png
# Iteration 50 completed in 17s
# Start of iteration 51
# Current loss value: 10427889.0
# Image saved as my_result_at_iteration_51.png
# Iteration 51 completed in 17s
# Start of iteration 52
# Current loss value: 10316795.0
# Image saved as my_result_at_iteration_52.png
# Iteration 52 completed in 17s
# Start of iteration 53
# Current loss value: 10207563.0
# Image saved as my_result_at_iteration_53.png
# Iteration 53 completed in 17s
# Start of iteration 54
# Current loss value: 10094996.0
# Image saved as my_result_at_iteration_54.png
# Iteration 54 completed in 17s
# Start of iteration 55
# Current loss value: 9953420.0
# Image saved as my_result_at_iteration_55.png
# Iteration 55 completed in 17s
# Start of iteration 56
# Current loss value: 9829440.0
# Image saved as my_result_at_iteration_56.png
# Iteration 56 completed in 17s
# Start of iteration 57
# Current loss value: 9732444.0
# Image saved as my_result_at_iteration_57.png
# Iteration 57 completed in 17s
# Start of iteration 58
# Current loss value: 9576806.0
# Image saved as my_result_at_iteration_58.png
# Iteration 58 completed in 17s
# Start of iteration 59
# Current loss value: 9415106.0
# Image saved as my_result_at_iteration_59.png
# Iteration 59 completed in 17s
# Start of iteration 60
# Current loss value: 9282916.0
# Image saved as my_result_at_iteration_60.png
# Iteration 60 completed in 17s
# Start of iteration 61
# Current loss value: 9191463.0
# Image saved as my_result_at_iteration_61.png
# Iteration 61 completed in 17s
# Start of iteration 62
# Current loss value: 9105707.0
# Image saved as my_result_at_iteration_62.png
# Iteration 62 completed in 17s
# Start of iteration 63
# Current loss value: 9017947.0
# Image saved as my_result_at_iteration_63.png
# Iteration 63 completed in 17s
# Start of iteration 64
# Current loss value: 8929081.0
# Image saved as my_result_at_iteration_64.png
# Iteration 64 completed in 17s
# Start of iteration 65
# Current loss value: 8805831.0
# Image saved as my_result_at_iteration_65.png
# Iteration 65 completed in 17s
# Start of iteration 66
# Current loss value: 8649810.0
# Image saved as my_result_at_iteration_66.png
# Iteration 66 completed in 17s
# Start of iteration 67
# Current loss value: 8539504.0
# Image saved as my_result_at_iteration_67.png
# Iteration 67 completed in 17s
# Start of iteration 68
# Current loss value: 8451964.0
# Image saved as my_result_at_iteration_68.png
# Iteration 68 completed in 17s
# Start of iteration 69
# Current loss value: 8371655.0
# Image saved as my_result_at_iteration_69.png
# Iteration 69 completed in 17s
# Start of iteration 70
# Current loss value: 8270443.5
# Image saved as my_result_at_iteration_70.png
# Iteration 70 completed in 17s
# Start of iteration 71
# Current loss value: 8182727.0
# Image saved as my_result_at_iteration_71.png
# Iteration 71 completed in 17s
# Start of iteration 72
# Current loss value: 8114788.0
# Image saved as my_result_at_iteration_72.png
# Iteration 72 completed in 17s
# Start of iteration 73
# Current loss value: 8046007.5
# Image saved as my_result_at_iteration_73.png
# Iteration 73 completed in 17s
# Start of iteration 74
# Current loss value: 7982487.5
# Image saved as my_result_at_iteration_74.png
# Iteration 74 completed in 17s
# Start of iteration 75
# Current loss value: 7907203.5
# Image saved as my_result_at_iteration_75.png
# Iteration 75 completed in 17s
# Start of iteration 76
# Current loss value: 7825636.0
# Image saved as my_result_at_iteration_76.png
# Iteration 76 completed in 17s
# Start of iteration 77
# Current loss value: 7755539.0
# Image saved as my_result_at_iteration_77.png
# Iteration 77 completed in 17s
# Start of iteration 78
# Current loss value: 7688653.5
# Image saved as my_result_at_iteration_78.png
# Iteration 78 completed in 17s
# Start of iteration 79
# Current loss value: 7631646.5
# Image saved as my_result_at_iteration_79.png
# Iteration 79 completed in 17s
# Start of iteration 80
# Current loss value: 7575676.5
# Image saved as my_result_at_iteration_80.png
# Iteration 80 completed in 17s
# Start of iteration 81
# Current loss value: 7520212.5
# Image saved as my_result_at_iteration_81.png
# Iteration 81 completed in 17s
# Start of iteration 82
# Current loss value: 7439800.0
# Image saved as my_result_at_iteration_82.png
# Iteration 82 completed in 17s
# Start of iteration 83
# Current loss value: 7372512.5
# Image saved as my_result_at_iteration_83.png
# Iteration 83 completed in 17s
# Start of iteration 84
# Current loss value: 7315342.0
# Image saved as my_result_at_iteration_84.png
# Iteration 84 completed in 17s
# Start of iteration 85
# Current loss value: 7259784.5
# Image saved as my_result_at_iteration_85.png
# Iteration 85 completed in 17s
# Start of iteration 86
# Current loss value: 7206722.5
# Image saved as my_result_at_iteration_86.png
# Iteration 86 completed in 17s
# Start of iteration 87
# Current loss value: 7152898.0
# Image saved as my_result_at_iteration_87.png
# Iteration 87 completed in 17s
# Start of iteration 88
# Current loss value: 7105587.5
# Image saved as my_result_at_iteration_88.png
# Iteration 88 completed in 17s
# Start of iteration 89
# Current loss value: 7054815.5
# Image saved as my_result_at_iteration_89.png
# Iteration 89 completed in 17s
# Start of iteration 90
# Current loss value: 6999301.0
# Image saved as my_result_at_iteration_90.png
# Iteration 90 completed in 17s
# Start of iteration 91
# Current loss value: 6947115.0
# Image saved as my_result_at_iteration_91.png
# Iteration 91 completed in 17s
# Start of iteration 92
# Current loss value: 6905620.5
# Image saved as my_result_at_iteration_92.png
# Iteration 92 completed in 17s
# Start of iteration 93
# Current loss value: 6856471.0
# Image saved as my_result_at_iteration_93.png
# Iteration 93 completed in 17s
# Start of iteration 94
# Current loss value: 6812901.5
# Image saved as my_result_at_iteration_94.png
# Iteration 94 completed in 17s
# Start of iteration 95
# Current loss value: 6755034.5
# Image saved as my_result_at_iteration_95.png
# Iteration 95 completed in 17s
# Start of iteration 96
# Current loss value: 6699897.0
# Image saved as my_result_at_iteration_96.png
# Iteration 96 completed in 17s
# Start of iteration 97
# Current loss value: 6650637.0
# Image saved as my_result_at_iteration_97.png
# Iteration 97 completed in 17s
# Start of iteration 98
# Current loss value: 6607981.5
# Image saved as my_result_at_iteration_98.png
# Iteration 98 completed in 17s
# Start of iteration 99
# Current loss value: 6562142.0
# Image saved as my_result_at_iteration_99.png
# Iteration 99 completed in 17s
# Start of iteration 100
# Current loss value: 6514755.0
# Image saved as my_result_at_iteration_100.png
# Iteration 100 completed in 17s
# Start of iteration 101
# Current loss value: 6470768.5
# Image saved as my_result_at_iteration_101.png
# Iteration 101 completed in 17s
# Start of iteration 102
# Current loss value: 6431874.0
# Image saved as my_result_at_iteration_102.png
# Iteration 102 completed in 17s
# Start of iteration 103
# Current loss value: 6391722.0
# Image saved as my_result_at_iteration_103.png
# Iteration 103 completed in 17s
# Start of iteration 104
# Current loss value: 6331741.5
# Image saved as my_result_at_iteration_104.png
# Iteration 104 completed in 17s
# Start of iteration 105
# Current loss value: 6275634.5
# Image saved as my_result_at_iteration_105.png
# Iteration 105 completed in 17s
# Start of iteration 106
# Current loss value: 6239988.0
# Image saved as my_result_at_iteration_106.png
# Iteration 106 completed in 17s
# Start of iteration 107
# Current loss value: 6204014.0
# Image saved as my_result_at_iteration_107.png
# Iteration 107 completed in 17s
# Start of iteration 108
# Current loss value: 6161473.5
# Image saved as my_result_at_iteration_108.png
# Iteration 108 completed in 17s
# Start of iteration 109
# Current loss value: 6122283.0
# Image saved as my_result_at_iteration_109.png
# Iteration 109 completed in 17s
# Start of iteration 110
# Current loss value: 6043381.5
# Image saved as my_result_at_iteration_110.png
# Iteration 110 completed in 17s
# Start of iteration 111
# Current loss value: 5977863.0
# Image saved as my_result_at_iteration_111.png
# Iteration 111 completed in 17s
# Start of iteration 112
# Current loss value: 5922665.0
# Image saved as my_result_at_iteration_112.png
# Iteration 112 completed in 17s
# Start of iteration 113
# Current loss value: 5870286.5
# Image saved as my_result_at_iteration_113.png
# Iteration 113 completed in 18s
# Start of iteration 114
# Current loss value: 5827650.5
# Image saved as my_result_at_iteration_114.png
# Iteration 114 completed in 17s
# Start of iteration 115
# Current loss value: 5786777.5
# Image saved as my_result_at_iteration_115.png
# Iteration 115 completed in 17s
# Start of iteration 116
# Current loss value: 5740245.0
# Image saved as my_result_at_iteration_116.png
# Iteration 116 completed in 17s
# Start of iteration 117
# Current loss value: 5697509.0
# Image saved as my_result_at_iteration_117.png
# Iteration 117 completed in 17s
# Start of iteration 118
# Current loss value: 5661168.0
# Image saved as my_result_at_iteration_118.png
# Iteration 118 completed in 17s
# Start of iteration 119
# Current loss value: 5614094.0
# Image saved as my_result_at_iteration_119.png
# Iteration 119 completed in 17s
# Start of iteration 120
# Current loss value: 5568656.0
# Image saved as my_result_at_iteration_120.png
# Iteration 120 completed in 17s
# Start of iteration 121
# Current loss value: 5519806.5
# Image saved as my_result_at_iteration_121.png
# Iteration 121 completed in 17s
# Start of iteration 122
# Current loss value: 5476076.0
# Image saved as my_result_at_iteration_122.png
# Iteration 122 completed in 17s
# Start of iteration 123
# Current loss value: 5436320.5
# Image saved as my_result_at_iteration_123.png
# Iteration 123 completed in 17s
# Start of iteration 124
# Current loss value: 5391904.0
# Image saved as my_result_at_iteration_124.png
# Iteration 124 completed in 17s
# Start of iteration 125
# Current loss value: 5350787.0
# Image saved as my_result_at_iteration_125.png
# Iteration 125 completed in 17s
# Start of iteration 126
# Current loss value: 5313987.0
# Image saved as my_result_at_iteration_126.png
# Iteration 126 completed in 17s
# Start of iteration 127
# Current loss value: 5271605.5
# Image saved as my_result_at_iteration_127.png
# Iteration 127 completed in 17s
# Start of iteration 128
# Current loss value: 5231671.0
# Image saved as my_result_at_iteration_128.png
# Iteration 128 completed in 17s
# Start of iteration 129
# Current loss value: 5195593.0
# Image saved as my_result_at_iteration_129.png
# Iteration 129 completed in 17s
# Start of iteration 130
# Current loss value: 5162799.0
# Image saved as my_result_at_iteration_130.png
# Iteration 130 completed in 17s
# Start of iteration 131
# Current loss value: 5129960.5
# Image saved as my_result_at_iteration_131.png
# Iteration 131 completed in 17s
# Start of iteration 132
# Current loss value: 5106699.5
# Image saved as my_result_at_iteration_132.png
# Iteration 132 completed in 17s
# Start of iteration 133
# Current loss value: 5076631.5
# Image saved as my_result_at_iteration_133.png
# Iteration 133 completed in 17s
# Start of iteration 134
# Current loss value: 5051795.5
# Image saved as my_result_at_iteration_134.png
# Iteration 134 completed in 17s
# Start of iteration 135
# Current loss value: 5026278.0
# Image saved as my_result_at_iteration_135.png
# Iteration 135 completed in 17s
# Start of iteration 136
# Current loss value: 4998953.5
# Image saved as my_result_at_iteration_136.png
# Iteration 136 completed in 17s
# Start of iteration 137
# Current loss value: 4977958.5
# Image saved as my_result_at_iteration_137.png
# Iteration 137 completed in 17s
# Start of iteration 138
# Current loss value: 4956850.5
# Image saved as my_result_at_iteration_138.png
# Iteration 138 completed in 17s
# Start of iteration 139
# Current loss value: 4930145.0
# Image saved as my_result_at_iteration_139.png
# Iteration 139 completed in 17s
# Start of iteration 140
# Current loss value: 4902582.0
# Image saved as my_result_at_iteration_140.png
# Iteration 140 completed in 17s
# Start of iteration 141
# Current loss value: 4876669.5
# Image saved as my_result_at_iteration_141.png
# Iteration 141 completed in 17s
# Start of iteration 142
# Current loss value: 4856215.0
# Image saved as my_result_at_iteration_142.png
# Iteration 142 completed in 17s
# Start of iteration 143
# Current loss value: 4821929.5
# Image saved as my_result_at_iteration_143.png
# Iteration 143 completed in 17s
# Start of iteration 144
# Current loss value: 4796350.5
# Image saved as my_result_at_iteration_144.png
# Iteration 144 completed in 17s
# Start of iteration 145
# Current loss value: 4769093.5
# Image saved as my_result_at_iteration_145.png
# Iteration 145 completed in 17s
# Start of iteration 146
# Current loss value: 4745404.0
# Image saved as my_result_at_iteration_146.png
# Iteration 146 completed in 17s
# Start of iteration 147
# Current loss value: 4721161.0
# Image saved as my_result_at_iteration_147.png
# Iteration 147 completed in 17s
# Start of iteration 148
# Current loss value: 4695194.5
# Image saved as my_result_at_iteration_148.png
# Iteration 148 completed in 17s
# Start of iteration 149
# Current loss value: 4675133.5
# Image saved as my_result_at_iteration_149.png
# Iteration 149 completed in 17s
# Start of iteration 150
# Current loss value: 4656323.0
# Image saved as my_result_at_iteration_150.png
# Iteration 150 completed in 17s
# Start of iteration 151
# Current loss value: 4638229.0
# Image saved as my_result_at_iteration_151.png
# Iteration 151 completed in 17s
# Start of iteration 152
# Current loss value: 4617739.5
# Image saved as my_result_at_iteration_152.png
# Iteration 152 completed in 17s
# Start of iteration 153
# Current loss value: 4594788.5
# Image saved as my_result_at_iteration_153.png
# Iteration 153 completed in 17s
# Start of iteration 154
# Current loss value: 4571450.0
# Image saved as my_result_at_iteration_154.png
# Iteration 154 completed in 17s
# Start of iteration 155
# Current loss value: 4552447.5
# Image saved as my_result_at_iteration_155.png
# Iteration 155 completed in 17s
# Start of iteration 156
# Current loss value: 4530550.5
# Image saved as my_result_at_iteration_156.png
# Iteration 156 completed in 17s
# Start of iteration 157
# Current loss value: 4508759.0
# Image saved as my_result_at_iteration_157.png
# Iteration 157 completed in 17s
# Start of iteration 158
# Current loss value: 4434191.5
# Image saved as my_result_at_iteration_158.png
# Iteration 158 completed in 17s
# Start of iteration 159
# Current loss value: 4378014.5
# Image saved as my_result_at_iteration_159.png
# Iteration 159 completed in 17s
# Start of iteration 160
# Current loss value: 4333962.5
# Image saved as my_result_at_iteration_160.png
# Iteration 160 completed in 17s
# Start of iteration 161
# Current loss value: 4299988.5
# Image saved as my_result_at_iteration_161.png
# Iteration 161 completed in 17s
# Start of iteration 162
# Current loss value: 4281219.5
# Image saved as my_result_at_iteration_162.png
# Iteration 162 completed in 17s
# Start of iteration 163
# Current loss value: 4266248.0
# Image saved as my_result_at_iteration_163.png
# Iteration 163 completed in 17s
# Start of iteration 164
# Current loss value: 4249062.5
# Image saved as my_result_at_iteration_164.png
# Iteration 164 completed in 17s
# Start of iteration 165
# Current loss value: 4233532.5
# Image saved as my_result_at_iteration_165.png
# Iteration 165 completed in 17s
# Start of iteration 166
# Current loss value: 4217829.0
# Image saved as my_result_at_iteration_166.png
# Iteration 166 completed in 17s
# Start of iteration 167
# Current loss value: 4203625.5
# Image saved as my_result_at_iteration_167.png
# Iteration 167 completed in 17s
# Start of iteration 168
# Current loss value: 4182212.8
# Image saved as my_result_at_iteration_168.png
# Iteration 168 completed in 17s
# Start of iteration 169
# Current loss value: 4159710.5
# Image saved as my_result_at_iteration_169.png
# Iteration 169 completed in 17s
# Start of iteration 170
# Current loss value: 4144946.2
# Image saved as my_result_at_iteration_170.png
# Iteration 170 completed in 17s
# Start of iteration 171
# Current loss value: 4128871.8
# Image saved as my_result_at_iteration_171.png
# Iteration 171 completed in 17s
# Start of iteration 172
# Current loss value: 4112181.5
# Image saved as my_result_at_iteration_172.png
# Iteration 172 completed in 17s
# Start of iteration 173
# Current loss value: 4094068.0
# Image saved as my_result_at_iteration_173.png
# Iteration 173 completed in 17s
# Start of iteration 174
# Current loss value: 4075486.0
# Image saved as my_result_at_iteration_174.png
# Iteration 174 completed in 18s
# Start of iteration 175
# Current loss value: 4049731.5
# Image saved as my_result_at_iteration_175.png
# Iteration 175 completed in 17s
# Start of iteration 176
# Current loss value: 4019884.2
# Image saved as my_result_at_iteration_176.png
# Iteration 176 completed in 17s
# Start of iteration 177
# Current loss value: 4000781.0
# Image saved as my_result_at_iteration_177.png
# Iteration 177 completed in 17s
# Start of iteration 178
# Current loss value: 3981982.2
# Image saved as my_result_at_iteration_178.png
# Iteration 178 completed in 17s
# Start of iteration 179
# Current loss value: 3965983.2
# Image saved as my_result_at_iteration_179.png
# Iteration 179 completed in 17s
# Start of iteration 180
# Current loss value: 3949882.2
# Image saved as my_result_at_iteration_180.png
# Iteration 180 completed in 18s
# Start of iteration 181
# Current loss value: 3937950.8
# Image saved as my_result_at_iteration_181.png
# Iteration 181 completed in 17s
# Start of iteration 182
# Current loss value: 3924558.0
# Image saved as my_result_at_iteration_182.png
# Iteration 182 completed in 17s
# Start of iteration 183
# Current loss value: 3910072.5
# Image saved as my_result_at_iteration_183.png
# Iteration 183 completed in 17s
# Start of iteration 184
# Current loss value: 3897084.8
# Image saved as my_result_at_iteration_184.png
# Iteration 184 completed in 17s
# Start of iteration 185
# Current loss value: 3884611.2
# Image saved as my_result_at_iteration_185.png
# Iteration 185 completed in 17s
# Start of iteration 186
# Current loss value: 3868026.2
# Image saved as my_result_at_iteration_186.png
# Iteration 186 completed in 17s
# Start of iteration 187
# Current loss value: 3853540.8
# Image saved as my_result_at_iteration_187.png
# Iteration 187 completed in 17s
# Start of iteration 188
# Current loss value: 3841601.8
# Image saved as my_result_at_iteration_188.png
# Iteration 188 completed in 17s
# Start of iteration 189
# Current loss value: 3825051.5
# Image saved as my_result_at_iteration_189.png
# Iteration 189 completed in 17s
# Start of iteration 190
# Current loss value: 3808496.8
# Image saved as my_result_at_iteration_190.png
# Iteration 190 completed in 17s
# Start of iteration 191
# Current loss value: 3794909.0
# Image saved as my_result_at_iteration_191.png
# Iteration 191 completed in 18s
# Start of iteration 192
# Current loss value: 3781811.8
# Image saved as my_result_at_iteration_192.png
# Iteration 192 completed in 17s
# Start of iteration 193
# Current loss value: 3768383.5
# Image saved as my_result_at_iteration_193.png
# Iteration 193 completed in 17s
# Start of iteration 194
# Current loss value: 3755541.0
# Image saved as my_result_at_iteration_194.png
# Iteration 194 completed in 17s
# Start of iteration 195
# Current loss value: 3732125.8
# Image saved as my_result_at_iteration_195.png
# Iteration 195 completed in 17s
# Start of iteration 196
# Current loss value: 3709308.8
# Image saved as my_result_at_iteration_196.png
# Iteration 196 completed in 17s
# Start of iteration 197
# Current loss value: 3695579.8
# Image saved as my_result_at_iteration_197.png
# Iteration 197 completed in 17s
# Start of iteration 198
# Current loss value: 3683404.8
# Image saved as my_result_at_iteration_198.png
# Iteration 198 completed in 18s
# Start of iteration 199
# Current loss value: 3671549.2
# Image saved as my_result_at_iteration_199.png
# Iteration 199 completed in 17s
# Start of iteration 200
# Current loss value: 3655807.8
# Image saved as my_result_at_iteration_200.png
# Iteration 200 completed in 17s
# Start of iteration 201
# Current loss value: 3640354.8
# Image saved as my_result_at_iteration_201.png
# Iteration 201 completed in 17s
# Start of iteration 202
# Current loss value: 3627890.5
# Image saved as my_result_at_iteration_202.png
# Iteration 202 completed in 17s
# Start of iteration 203
# Current loss value: 3614353.8
# Image saved as my_result_at_iteration_203.png
# Iteration 203 completed in 17s
# Start of iteration 204
# Current loss value: 3598609.8
# Image saved as my_result_at_iteration_204.png
# Iteration 204 completed in 17s
# Start of iteration 205
# Current loss value: 3583736.0
# Image saved as my_result_at_iteration_205.png
# Iteration 205 completed in 17s
# Start of iteration 206
# Current loss value: 3567051.5
# Image saved as my_result_at_iteration_206.png
# Iteration 206 completed in 17s
# Start of iteration 207
# Current loss value: 3550421.2
# Image saved as my_result_at_iteration_207.png
# Iteration 207 completed in 17s
# Start of iteration 208
# Current loss value: 3536722.5
# Image saved as my_result_at_iteration_208.png
# Iteration 208 completed in 17s
# Start of iteration 209
# Current loss value: 3524373.5
# Image saved as my_result_at_iteration_209.png
# Iteration 209 completed in 17s
# Start of iteration 210
# Current loss value: 3508543.0
# Image saved as my_result_at_iteration_210.png
# Iteration 210 completed in 17s
# Start of iteration 211
# Current loss value: 3492119.8
# Image saved as my_result_at_iteration_211.png
# Iteration 211 completed in 17s
# Start of iteration 212
# Current loss value: 3476660.0
# Image saved as my_result_at_iteration_212.png
# Iteration 212 completed in 17s
# Start of iteration 213
# Current loss value: 3462017.2
# Image saved as my_result_at_iteration_213.png
# Iteration 213 completed in 18s
# Start of iteration 214
# Current loss value: 3450237.2
# Image saved as my_result_at_iteration_214.png
# Iteration 214 completed in 17s
# Start of iteration 215
# Current loss value: 3438326.5
# Image saved as my_result_at_iteration_215.png
# Iteration 215 completed in 17s
# Start of iteration 216
# Current loss value: 3409790.2
# Image saved as my_result_at_iteration_216.png
# Iteration 216 completed in 17s
# Start of iteration 217
# Current loss value: 3374108.5
# Image saved as my_result_at_iteration_217.png
# Iteration 217 completed in 17s
# Start of iteration 218
# Current loss value: 3362061.2
# Image saved as my_result_at_iteration_218.png
# Iteration 218 completed in 17s
# Start of iteration 219
# Current loss value: 3348629.0
# Image saved as my_result_at_iteration_219.png
# Iteration 219 completed in 17s
# Start of iteration 220
# Current loss value: 3336643.5
# Image saved as my_result_at_iteration_220.png
# Iteration 220 completed in 18s
# Start of iteration 221
# Current loss value: 3326066.2
# Image saved as my_result_at_iteration_221.png
# Iteration 221 completed in 17s
# Start of iteration 222
# Current loss value: 3316325.5
# Image saved as my_result_at_iteration_222.png
# Iteration 222 completed in 17s
# Start of iteration 223
# Current loss value: 3306536.0
# Image saved as my_result_at_iteration_223.png
# Iteration 223 completed in 17s
# Start of iteration 224
# Current loss value: 3296251.2
# Image saved as my_result_at_iteration_224.png
# Iteration 224 completed in 17s
# Start of iteration 225
# Current loss value: 3281011.8
# Image saved as my_result_at_iteration_225.png
# Iteration 225 completed in 17s
# Start of iteration 226
# Current loss value: 3270264.2
# Image saved as my_result_at_iteration_226.png
# Iteration 226 completed in 17s
# Start of iteration 227
# Current loss value: 3259041.0
# Image saved as my_result_at_iteration_227.png
# Iteration 227 completed in 17s
# Start of iteration 228
# Current loss value: 3249223.8
# Image saved as my_result_at_iteration_228.png
# Iteration 228 completed in 17s
# Start of iteration 229
# Current loss value: 3238746.2
# Image saved as my_result_at_iteration_229.png
# Iteration 229 completed in 17s
# Start of iteration 230
# Current loss value: 3228215.8
# Image saved as my_result_at_iteration_230.png
# Iteration 230 completed in 17s
# Start of iteration 231
# Current loss value: 3217545.5
# Image saved as my_result_at_iteration_231.png
# Iteration 231 completed in 17s
# Start of iteration 232
# Current loss value: 3206250.2
# Image saved as my_result_at_iteration_232.png
# Iteration 232 completed in 17s
# Start of iteration 233
# Current loss value: 3191938.8
# Image saved as my_result_at_iteration_233.png
# Iteration 233 completed in 17s
# Start of iteration 234
# Current loss value: 3179165.2
# Image saved as my_result_at_iteration_234.png
# Iteration 234 completed in 17s
# Start of iteration 235
# Current loss value: 3167950.8
# Image saved as my_result_at_iteration_235.png
# Iteration 235 completed in 17s
# Start of iteration 236
# Current loss value: 3157027.2
# Image saved as my_result_at_iteration_236.png
# Iteration 236 completed in 17s
# Start of iteration 237
# Current loss value: 3147697.2
# Image saved as my_result_at_iteration_237.png
# Iteration 237 completed in 17s
# Start of iteration 238
# Current loss value: 3137224.5
# Image saved as my_result_at_iteration_238.png
# Iteration 238 completed in 17s
# Start of iteration 239
# Current loss value: 3128134.2
# Image saved as my_result_at_iteration_239.png
# Iteration 239 completed in 17s
# Start of iteration 240
# Current loss value: 3115971.5
# Image saved as my_result_at_iteration_240.png
# Iteration 240 completed in 17s
# Start of iteration 241
# Current loss value: 3105904.2
# Image saved as my_result_at_iteration_241.png
# Iteration 241 completed in 17s
# Start of iteration 242
# Current loss value: 3098412.8
# Image saved as my_result_at_iteration_242.png
# Iteration 242 completed in 17s
# Start of iteration 243
# Current loss value: 3088269.8
# Image saved as my_result_at_iteration_243.png
# Iteration 243 completed in 17s
# Start of iteration 244
# Current loss value: 3070542.5
# Image saved as my_result_at_iteration_244.png
# Iteration 244 completed in 17s
# Start of iteration 245
# Current loss value: 3059914.8
# Image saved as my_result_at_iteration_245.png
# Iteration 245 completed in 17s
# Start of iteration 246
# Current loss value: 3049832.0
# Image saved as my_result_at_iteration_246.png
# Iteration 246 completed in 17s
# Start of iteration 247
# Current loss value: 3039601.0
# Image saved as my_result_at_iteration_247.png
# Iteration 247 completed in 17s
# Start of iteration 248
# Current loss value: 3031482.8
# Image saved as my_result_at_iteration_248.png
# Iteration 248 completed in 17s
# Start of iteration 249
# Current loss value: 3023214.2
# Image saved as my_result_at_iteration_249.png
# Iteration 249 completed in 17s
# Start of iteration 250
# Current loss value: 3015914.2
# Image saved as my_result_at_iteration_250.png
# Iteration 250 completed in 17s
# Start of iteration 251
# Current loss value: 3002026.0
# Image saved as my_result_at_iteration_251.png
# Iteration 251 completed in 17s
# Start of iteration 252
# Current loss value: 2989788.5
# Image saved as my_result_at_iteration_252.png
# Iteration 252 completed in 17s
# Start of iteration 253
# Current loss value: 2983324.2
# Image saved as my_result_at_iteration_253.png
# Iteration 253 completed in 17s
# Start of iteration 254
# Current loss value: 2973446.8
# Image saved as my_result_at_iteration_254.png
# Iteration 254 completed in 17s
# Start of iteration 255
# Current loss value: 2963806.2
# Image saved as my_result_at_iteration_255.png
# Iteration 255 completed in 17s
# Start of iteration 256
# Current loss value: 2954940.5
# Image saved as my_result_at_iteration_256.png
# Iteration 256 completed in 17s
# Start of iteration 257
# Current loss value: 2946991.5
# Image saved as my_result_at_iteration_257.png
# Iteration 257 completed in 17s
# Start of iteration 258
# Current loss value: 2938926.5
# Image saved as my_result_at_iteration_258.png
# Iteration 258 completed in 17s
# Start of iteration 259
# Current loss value: 2926483.0
# Image saved as my_result_at_iteration_259.png
# Iteration 259 completed in 17s
# Start of iteration 260
# Current loss value: 2913782.5
# Image saved as my_result_at_iteration_260.png
# Iteration 260 completed in 17s
# Start of iteration 261
# Current loss value: 2903826.5
# Image saved as my_result_at_iteration_261.png
# Iteration 261 completed in 17s
# Start of iteration 262
# Current loss value: 2892673.2
# Image saved as my_result_at_iteration_262.png
# Iteration 262 completed in 17s
# Start of iteration 263
# Current loss value: 2881733.8
# Image saved as my_result_at_iteration_263.png
# Iteration 263 completed in 17s
# Start of iteration 264
# Current loss value: 2871632.2
# Image saved as my_result_at_iteration_264.png
# Iteration 264 completed in 17s
# Start of iteration 265
# Current loss value: 2863584.2
# Image saved as my_result_at_iteration_265.png
# Iteration 265 completed in 17s
# Start of iteration 266
# Current loss value: 2855857.0
# Image saved as my_result_at_iteration_266.png
# Iteration 266 completed in 17s
# Start of iteration 267
# Current loss value: 2844628.0
# Image saved as my_result_at_iteration_267.png
# Iteration 267 completed in 17s
# Start of iteration 268
# Current loss value: 2832857.2
# Image saved as my_result_at_iteration_268.png
# Iteration 268 completed in 17s
# Start of iteration 269
# Current loss value: 2824609.5
# Image saved as my_result_at_iteration_269.png
# Iteration 269 completed in 17s
# Start of iteration 270
# Current loss value: 2816595.0
# Image saved as my_result_at_iteration_270.png
# Iteration 270 completed in 18s
# Start of iteration 271
# Current loss value: 2809455.0
# Image saved as my_result_at_iteration_271.png
# Iteration 271 completed in 17s
# Start of iteration 272
# Current loss value: 2801841.0
# Image saved as my_result_at_iteration_272.png
# Iteration 272 completed in 17s
# Start of iteration 273
# Current loss value: 2794505.8
# Image saved as my_result_at_iteration_273.png
# Iteration 273 completed in 17s
# Start of iteration 274
# Current loss value: 2787187.8
# Image saved as my_result_at_iteration_274.png
# Iteration 274 completed in 17s
# Start of iteration 275
# Current loss value: 2780909.0
# Image saved as my_result_at_iteration_275.png
# Iteration 275 completed in 17s
# Start of iteration 276
# Current loss value: 2772656.2
# Image saved as my_result_at_iteration_276.png
# Iteration 276 completed in 17s
# Start of iteration 277
# Current loss value: 2766184.8
# Image saved as my_result_at_iteration_277.png
# Iteration 277 completed in 17s
# Start of iteration 278
# Current loss value: 2758819.0
# Image saved as my_result_at_iteration_278.png
# Iteration 278 completed in 17s
# Start of iteration 279
# Current loss value: 2752486.0
# Image saved as my_result_at_iteration_279.png
# Iteration 279 completed in 17s
# Start of iteration 280
# Current loss value: 2746825.5
# Image saved as my_result_at_iteration_280.png
# Iteration 280 completed in 17s
# Start of iteration 281
# Current loss value: 2740809.5
# Image saved as my_result_at_iteration_281.png
# Iteration 281 completed in 17s
# Start of iteration 282
# Current loss value: 2733801.5
# Image saved as my_result_at_iteration_282.png
# Iteration 282 completed in 17s
# Start of iteration 283
# Current loss value: 2727326.5
# Image saved as my_result_at_iteration_283.png
# Iteration 283 completed in 17s
# Start of iteration 284
# Current loss value: 2719567.5
# Image saved as my_result_at_iteration_284.png
# Iteration 284 completed in 17s
# Start of iteration 285
# Current loss value: 2713642.0
# Image saved as my_result_at_iteration_285.png
# Iteration 285 completed in 17s
# Start of iteration 286
# Current loss value: 2707797.5
# Image saved as my_result_at_iteration_286.png
# Iteration 286 completed in 17s
# Start of iteration 287
# Current loss value: 2696175.2
# Image saved as my_result_at_iteration_287.png
# Iteration 287 completed in 17s
# Start of iteration 288
# Current loss value: 2686327.8
# Image saved as my_result_at_iteration_288.png
# Iteration 288 completed in 17s
# Start of iteration 289
# Current loss value: 2677009.2
# Image saved as my_result_at_iteration_289.png
# Iteration 289 completed in 17s
# Start of iteration 290
# Current loss value: 2667424.5
# Image saved as my_result_at_iteration_290.png
# Iteration 290 completed in 17s
# Start of iteration 291
# Current loss value: 2660232.0
# Image saved as my_result_at_iteration_291.png
# Iteration 291 completed in 17s
# Start of iteration 292
# Current loss value: 2653422.5
# Image saved as my_result_at_iteration_292.png
# Iteration 292 completed in 17s
# Start of iteration 293
# Current loss value: 2648295.5
# Image saved as my_result_at_iteration_293.png
# Iteration 293 completed in 17s
# Start of iteration 294
# Current loss value: 2642650.0
# Image saved as my_result_at_iteration_294.png
# Iteration 294 completed in 17s
# Start of iteration 295
# Current loss value: 2635085.5
# Image saved as my_result_at_iteration_295.png
# Iteration 295 completed in 17s
# Start of iteration 296
# Current loss value: 2628011.5
# Image saved as my_result_at_iteration_296.png
# Iteration 296 completed in 17s
# Start of iteration 297
# Current loss value: 2620463.5
# Image saved as my_result_at_iteration_297.png
# Iteration 297 completed in 17s
# Start of iteration 298
# Current loss value: 2613628.8
# Image saved as my_result_at_iteration_298.png
# Iteration 298 completed in 17s
# Start of iteration 299
# Current loss value: 2603378.5
# Image saved as my_result_at_iteration_299.png
# Iteration 299 completed in 17s
# Start of iteration 300
# Current loss value: 2595164.5
# Image saved as my_result_at_iteration_300.png
# Iteration 300 completed in 17s
# Start of iteration 301
# Current loss value: 2588255.0
# Image saved as my_result_at_iteration_301.png
# Iteration 301 completed in 17s
# Start of iteration 302
# Current loss value: 2582246.8
# Image saved as my_result_at_iteration_302.png
# Iteration 302 completed in 17s
# Start of iteration 303
# Current loss value: 2576602.2
# Image saved as my_result_at_iteration_303.png
# Iteration 303 completed in 17s
# Start of iteration 304
# Current loss value: 2571152.8
# Image saved as my_result_at_iteration_304.png
# Iteration 304 completed in 17s
# Start of iteration 305
# Current loss value: 2566396.0
# Image saved as my_result_at_iteration_305.png
# Iteration 305 completed in 17s
# Start of iteration 306
# Current loss value: 2561764.8
# Image saved as my_result_at_iteration_306.png
# Iteration 306 completed in 17s
# Start of iteration 307
# Current loss value: 2556668.2
# Image saved as my_result_at_iteration_307.png
# Iteration 307 completed in 17s
# Start of iteration 308
# Current loss value: 2551670.2
# Image saved as my_result_at_iteration_308.png
# Iteration 308 completed in 17s
# Start of iteration 309
# Current loss value: 2546656.8
# Image saved as my_result_at_iteration_309.png
# Iteration 309 completed in 17s
# Start of iteration 310
